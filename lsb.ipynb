# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img=np.array(Image.open ("Images/treeBW.png"))

# %%
plt.imshow(img, cmap = "gray")

# %%
W,H,C= img.shape

# %%
W,H,C
# Out:
# (835, 1256, 3)

# %%
message = input ()
message += "[END]"
message = message.encode("ascii")
message_bits = ''.join([format(i,'08b')for i in message])

# %%
img = img.flatten()

for idx,bit in enumerate(message_bits):
    val = img[idx] 
    val = bin(val)
    val = val[:-1]+bit
    img[idx] = int(val,2)
img = img.reshape((W,H,C))

# %%
plt.imshow(img, cmap = "gray")

# %%
msg = ""
idx=0
img = img.flatten() 
while msg[-5:] != '[END]' : 
    bits = ''.join([bin(i)[-1] for i in img[idx:idx+8]])  # Convertit en une chaîne binaire
    msg += chr(int(bits, 2))  # Convertit cette chaîne en un caractère
    idx+=8
    if idx > img.shape [0] :
        print("there is no hdden message")
        break
